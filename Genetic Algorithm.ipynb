# %%
import random
# Number of individuals in each generation
POPULATION_SIZE = 100

# Valid genes
GENES = '''abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOP
QRSTUVWXYZ 1234567890, .-;:_!"#%&/()=?@${[]}'''

# Target string to be generated
TARGET = "Aakarshit Srivastava"

class Individual(object):
	'''
	Class representing individual in population
	'''
	def __init__(self, chromosome):
		self.chromosome = chromosome 
		self.fitness = self.cal_fitness()

	@classmethod
	def mutated_genes(self):
		'''
		create random genes for mutation
		'''
		global GENES
		gene = random.choice(GENES)
		return gene

	@classmethod
	def create_gnome(self):
		'''
		create chromosome or string of genes
		'''
		global TARGET
		gnome_len = len(TARGET)
		return [self.mutated_genes() for _ in range(gnome_len)]

	def mate(self, par2):
		'''
		Perform mating and produce new offspring
		'''

		# chromosome for offspring
		child_chromosome = []
		for gp1, gp2 in zip(self.chromosome, par2.chromosome): 

			# random probability 
			prob = random.random()

			# if prob is less than 0.45, insert gene
			# from parent 1 
			if prob < 0.45:
				child_chromosome.append(gp1)

			# if prob is between 0.45 and 0.90, insert
			# gene from parent 2
			elif prob < 0.90:
				child_chromosome.append(gp2)

			# otherwise insert random gene(mutate), 
			# for maintaining diversity
			else:
				child_chromosome.append(self.mutated_genes())

		# create new Individual(offspring) using 
		# generated chromosome for offspring
		return Individual(child_chromosome)

	def cal_fitness(self):
		'''
		Calculate fitness score, it is the number of
		characters in string which differ from target
		string.
		'''
		global TARGET
		fitness = 0
		for gs, gt in zip(self.chromosome, TARGET):
			if gs != gt: fitness+= 1
		return fitness

# Driver code
def main():
	global POPULATION_SIZE

	#current generation
	generation = 1

	found = False
	population = []

	# create initial population
	for _ in range(POPULATION_SIZE):
				gnome = Individual.create_gnome()
				population.append(Individual(gnome))

	while not found:

		# sort the population in increasing order of fitness score
		population = sorted(population, key = lambda x:x.fitness)

		# if the individual having lowest fitness score ie. 
		# 0 then we know that we have reached to the target
		# and break the loop
		if population[0].fitness <= 0:
			found = True
			break

		# Otherwise generate new offsprings for new generation
		new_generation = []

		# Perform Elitism, that mean 10% of fittest population
		# goes to the next generation
		s = int((10*POPULATION_SIZE)/100)
		new_generation.extend(population[:s])

		# From 50% of fittest population, Individuals 
		# will mate to produce offspring
		s = int((90*POPULATION_SIZE)/100)
		for _ in range(s):
			parent1 = random.choice(population[:50])
			parent2 = random.choice(population[:50])
			child = parent1.mate(parent2)
			new_generation.append(child)

		population = new_generation

		print("Generation: {}\tString: {}\tFitness: {}".\
			format(generation,
			"".join(population[0].chromosome),
			population[0].fitness))

		generation += 1

	
	print("Generation: {}\tString: {}\tFitness: {}".\
		format(generation,
		"".join(population[0].chromosome),
		population[0].fitness))

if __name__ == '__main__':
	main()
# Out:
# Generation: 1	String: JNQE9seX&:GrKClxvtdI	Fitness: 18
# Generation: 2	String: JNQE9seX&:GrKClxvtdI	Fitness: 18
# Generation: 3	String: JNQE9seX&:GrKClxvtdI	Fitness: 18
# Generation: 4	String: !7QIespj&A]rT&.mt"La	Fitness: 16
# Generation: 5	String:  7bzbsxi d%g@v:qtHIa	Fitness: 15
# Generation: 6	String: }aY%fs&XR#STHvJsttd:	Fitness: 14
# Generation: 7	String: }aY%fs&XR#STHvJsttd:	Fitness: 14
# Generation: 8	String: }7WaLsp% 1Sr@v:jt:Ra	Fitness: 13
# Generation: 9	String: }7WaLsp% 1Sr@v:jt:Ra	Fitness: 13
# Generation: 10	String:  aWx shZ:
# r@vasYHAa	Fitness: 11
# Generation: 11	String: y7Yar0xi pSr@vast#va	Fitness: 9
# Generation: 12	String: y7Yar0xi pSr@vast#va	Fitness: 9
# Generation: 13	String: y7Yar0xi pSr@vast#va	Fitness: 9
# Generation: 14	String: ylYarshU&,Sr8vast$va	Fitness: 8
# Generation: 15	String: ylYarshU&,Sr8vast$va	Fitness: 8
# Generation: 16	String: ylYarshU&,Sr8vast$va	Fitness: 8
# Generation: 17	String: ylYarshU&,Sr8vast$va	Fitness: 8
# Generation: 18	String: 3akarshi zSrevastY3a	Fitness: 6
# Generation: 19	String: 3akarshi zSrevastY3a	Fitness: 6
# Generation: 20	String: 3akarshi zSrevastY3a	Fitness: 6
# Generation: 21	String: 3akarshi zSrevastY3a	Fitness: 6
# Generation: 22	String: yakarshilASrhvastYva	Fitness: 5
# Generation: 23	String: yakarshilASrhvastYva	Fitness: 5
# Generation: 24	String: yakarshilASrhvastYva	Fitness: 5
# Generation: 25	String: yakarshilASrhvastYva	Fitness: 5
# Generation: 26	String: yakarshilASrhvastYva	Fitness: 5
# Generation: 27	String: vakarshia Sr@vast%va	Fitness: 4
# Generation: 28	String: vakarshia Sr@vast%va	Fitness: 4
# Generation: 29	String: vakarshia Sr@vast%va	Fitness: 4
# Generation: 30	String: vakarshia Sr@vast%va	Fitness: 4
# Generation: 31	String: vakarshia Sr@vast%va	Fitness: 4
# Generation: 32	String: vakarshia Sr@vast%va	Fitness: 4
# Generation: 33	String: yakarshit SrfvastYva	Fitness: 3
# Generation: 34	String: yakarshit SrfvastYva	Fitness: 3
# Generation: 35	String: yakarshit SrfvastYva	Fitness: 3
# Generation: 36	String: yakarshit SrfvastYva	Fitness: 3
# Generation: 37	String: yakarshit SrfvastYva	Fitness: 3
# Generation: 38	String: yakarshit SrfvastYva	Fitness: 3
# Generation: 39	String: yakarshit SrfvastYva	Fitness: 3
# Generation: 40	String: yakarshit SrfvastYva	Fitness: 3
# Generation: 41	String: yakarshit SrfvastYva	Fitness: 3
# Generation: 42	String: yakarshit SrfvastYva	Fitness: 3
# Generation: 43	String: Aakarshat SrivastKva	Fitness: 2
# Generation: 44	String: Aakarshat SrivastKva	Fitness: 2
# Generation: 45	String: Aakarshat SrivastKva	Fitness: 2
# Generation: 46	String: Aakarshat SrivastKva	Fitness: 2
# Generation: 47	String: Aakarshat SrivastKva	Fitness: 2
# Generation: 48	String: Aakarshat SrivastKva	Fitness: 2
# Generation: 49	String: Aakarshat SrivastKva	Fitness: 2
# Generation: 50	String: Aakarshat SrivastKva	Fitness: 2
# Generation: 51	String: Aakarshat SrivastKva	Fitness: 2
# Generation: 52	String: Aakarshit SrivastUva	Fitness: 1
# Generation: 53	String: Aakarshit SrivastUva	Fitness: 1
# Generation: 54	String: Aakarshit SrivastUva	Fitness: 1
# Generation: 55	String: Aakarshit SrivastUva	Fitness: 1
# Generation: 56	String: Aakarshit SrivastUva	Fitness: 1
# Generation: 57	String: Aakarshit SrivastUva	Fitness: 1
# Generation: 58	String: Aakarshit SrivastUva	Fitness: 1
# Generation: 59	String: Aakarshit SrivastUva	Fitness: 1
# Generation: 60	String: Aakarshit SrivastUva	Fitness: 1
# Generation: 61	String: Aakarshit SrivastUva	Fitness: 1
# Generation: 62	String: Aakarshit SrivastUva	Fitness: 1
# Generation: 63	String: Aakarshit SrivastUva	Fitness: 1
# Generation: 64	String: Aakarshit SrivastUva	Fitness: 1
# Generation: 65	String: Aakarshit SrivastUva	Fitness: 1
# Generation: 66	String: Aakarshit SrivastUva	Fitness: 1
# Generation: 67	String: Aakarshit SrivastUva	Fitness: 1
# Generation: 68	String: Aakarshit SrivastUva	Fitness: 1
# Generation: 69	String: Aakarshit SrivastUva	Fitness: 1
# Generation: 70	String: Aakarshit SrivastUva	Fitness: 1
# Generation: 71	String: Aakarshit SrivastUva	Fitness: 1
# Generation: 72	String: Aakarshit SrivastUva	Fitness: 1
# Generation: 73	String: Aakarshit SrivastUva	Fitness: 1
# Generation: 74	String: Aakarshit SrivastUva	Fitness: 1
# Generation: 75	String: Aakarshit SrivastUva	Fitness: 1
# Generation: 76	String: Aakarshit SrivastUva	Fitness: 1
# Generation: 77	String: Aakarshit SrivastUva	Fitness: 1
# Generation: 78	String: Aakarshit SrivastUva	Fitness: 1
# Generation: 79	String: Aakarshit SrivastUva	Fitness: 1
# Generation: 80	String: Aakarshit SrivastUva	Fitness: 1
# Generation: 81	String: Aakarshit SrivastUva	Fitness: 1
# Generation: 82	String: Aakarshit SrivastUva	Fitness: 1
# Generation: 83	String: Aakarshit SrivastUva	Fitness: 1
# Generation: 84	String: Aakarshit SrivastUva	Fitness: 1
# Generation: 85	String: Aakarshit SrivastUva	Fitness: 1
# Generation: 86	String: Aakarshit SrivastUva	Fitness: 1
# Generation: 87	String: Aakarshit SrivastUva	Fitness: 1
# Generation: 88	String: Aakarshit SrivastUva	Fitness: 1
# Generation: 89	String: Aakarshit SrivastUva	Fitness: 1
# Generation: 90	String: Aakarshit SrivastUva	Fitness: 1
# Generation: 91	String: Aakarshit SrivastUva	Fitness: 1
# Generation: 92	String: Aakarshit SrivastUva	Fitness: 1
# Generation: 93	String: Aakarshit SrivastUva	Fitness: 1
# Generation: 94	String: Aakarshit SrivastUva	Fitness: 1
# Generation: 95	String: Aakarshit SrivastUva	Fitness: 1
# Generation: 96	String: Aakarshit SrivastUva	Fitness: 1
# Generation: 97	String: Aakarshit SrivastUva	Fitness: 1
# Generation: 98	String: Aakarshit SrivastUva	Fitness: 1
# Generation: 99	String: Aakarshit SrivastUva	Fitness: 1
# Generation: 100	String: Aakarshit SrivastUva	Fitness: 1
# Generation: 101	String: Aakarshit SrivastUva	Fitness: 1
# Generation: 102	String: Aakarshit SrivastUva	Fitness: 1
# Generation: 103	String: Aakarshit SrivastUva	Fitness: 1
# Generation: 104	String: Aakarshit SrivastUva	Fitness: 1
# Generation: 105	String: Aakarshit SrivastUva	Fitness: 1
# Generation: 106	String: Aakarshit SrivastUva	Fitness: 1
# Generation: 107	String: Aakarshit SrivastUva	Fitness: 1
# Generation: 108	String: Aakarshit SrivastUva	Fitness: 1
# Generation: 109	String: Aakarshit SrivastUva	Fitness: 1
# Generation: 110	String: Aakarshit SrivastUva	Fitness: 1
# Generation: 111	String: Aakarshit SrivastUva	Fitness: 1
# Generation: 112	String: Aakarshit SrivastUva	Fitness: 1
# Generation: 113	String: Aakarshit SrivastUva	Fitness: 1
# Generation: 114	String: Aakarshit SrivastUva	Fitness: 1
# Generation: 115	String: Aakarshit SrivastUva	Fitness: 1
# Generation: 116	String: Aakarshit SrivastUva	Fitness: 1
# Generation: 117	String: Aakarshit SrivastUva	Fitness: 1
# Generation: 118	String: Aakarshit SrivastUva	Fitness: 1
# Generation: 119	String: Aakarshit SrivastUva	Fitness: 1
# Generation: 120	String: Aakarshit SrivastUva	Fitness: 1
# Generation: 121	String: Aakarshit SrivastUva	Fitness: 1
# Generation: 122	String: Aakarshit SrivastUva	Fitness: 1
# Generation: 123	String: Aakarshit SrivastUva	Fitness: 1
# Generation: 124	String: Aakarshit SrivastUva	Fitness: 1
# Generation: 125	String: Aakarshit SrivastUva	Fitness: 1
# Generation: 126	String: Aakarshit SrivastUva	Fitness: 1
# Generation: 127	String: Aakarshit SrivastUva	Fitness: 1
# Generation: 128	String: Aakarshit SrivastUva	Fitness: 1
# Generation: 129	String: Aakarshit SrivastUva	Fitness: 1
# Generation: 130	String: Aakarshit SrivastUva	Fitness: 1
# Generation: 131	String: Aakarshit SrivastUva	Fitness: 1
# Generation: 132	String: Aakarshit SrivastUva	Fitness: 1
# Generation: 133	String: Aakarshit SrivastUva	Fitness: 1
# Generation: 134	String: Aakarshit SrivastUva	Fitness: 1
# Generation: 135	String: Aakarshit SrivastUva	Fitness: 1
# Generation: 136	String: Aakarshit SrivastUva	Fitness: 1
# Generation: 137	String: Aakarshit SrivastUva	Fitness: 1
# Generation: 138	String: Aakarshit SrivastUva	Fitness: 1
# Generation: 139	String: Aakarshit SrivastUva	Fitness: 1
# Generation: 140	String: Aakarshit SrivastUva	Fitness: 1
# Generation: 141	String: Aakarshit SrivastUva	Fitness: 1
# Generation: 142	String: Aakarshit SrivastUva	Fitness: 1
# Generation: 143	String: Aakarshit SrivastUva	Fitness: 1
# Generation: 144	String: Aakarshit SrivastUva	Fitness: 1
# Generation: 145	String: Aakarshit SrivastUva	Fitness: 1
# Generation: 146	String: Aakarshit SrivastUva	Fitness: 1
# Generation: 147	String: Aakarshit SrivastUva	Fitness: 1
# Generation: 148	String: Aakarshit SrivastUva	Fitness: 1
# Generation: 149	String: Aakarshit SrivastUva	Fitness: 1
# Generation: 150	String: Aakarshit SrivastUva	Fitness: 1
# Generation: 151	String: Aakarshit SrivastUva	Fitness: 1
# Generation: 152	String: Aakarshit SrivastUva	Fitness: 1
# Generation: 153	String: Aakarshit SrivastUva	Fitness: 1
# Generation: 154	String: Aakarshit SrivastUva	Fitness: 1
# Generation: 155	String: Aakarshit SrivastUva	Fitness: 1
# Generation: 156	String: Aakarshit SrivastUva	Fitness: 1
# Generation: 157	String: Aakarshit SrivastUva	Fitness: 1
# Generation: 158	String: Aakarshit SrivastUva	Fitness: 1
# Generation: 159	String: Aakarshit SrivastUva	Fitness: 1
# Generation: 160	String: Aakarshit SrivastUva	Fitness: 1
# Generation: 161	String: Aakarshit SrivastUva	Fitness: 1
# Generation: 162	String: Aakarshit SrivastUva	Fitness: 1
# Generation: 163	String: Aakarshit SrivastUva	Fitness: 1
# Generation: 164	String: Aakarshit SrivastUva	Fitness: 1
# Generation: 165	String: Aakarshit SrivastUva	Fitness: 1
# Generation: 166	String: Aakarshit SrivastUva	Fitness: 1
# Generation: 167	String: Aakarshit SrivastUva	Fitness: 1
# Generation: 168	String: Aakarshit SrivastUva	Fitness: 1
# Generation: 169	String: Aakarshit SrivastUva	Fitness: 1
# Generation: 170	String: Aakarshit SrivastUva	Fitness: 1
# Generation: 171	String: Aakarshit SrivastUva	Fitness: 1
# Generation: 172	String: Aakarshit SrivastUva	Fitness: 1
# Generation: 173	String: Aakarshit SrivastUva	Fitness: 1
# Generation: 174	String: Aakarshit SrivastUva	Fitness: 1
# Generation: 175	String: Aakarshit SrivastUva	Fitness: 1
# Generation: 176	String: Aakarshit SrivastUva	Fitness: 1
# Generation: 177	String: Aakarshit SrivastUva	Fitness: 1
# Generation: 178	String: Aakarshit SrivastUva	Fitness: 1
# Generation: 179	String: Aakarshit SrivastUva	Fitness: 1
# Generation: 180	String: Aakarshit SrivastUva	Fitness: 1
# Generation: 181	String: Aakarshit SrivastUva	Fitness: 1
# Generation: 182	String: Aakarshit SrivastUva	Fitness: 1
# Generation: 183	String: Aakarshit SrivastUva	Fitness: 1
# Generation: 184	String: Aakarshit SrivastUva	Fitness: 1
# Generation: 185	String: Aakarshit SrivastUva	Fitness: 1
# Generation: 186	String: Aakarshit SrivastUva	Fitness: 1
# Generation: 187	String: Aakarshit SrivastUva	Fitness: 1
# Generation: 188	String: Aakarshit SrivastUva	Fitness: 1
# Generation: 189	String: Aakarshit SrivastUva	Fitness: 1
# Generation: 190	String: Aakarshit SrivastUva	Fitness: 1
# Generation: 191	String: Aakarshit SrivastUva	Fitness: 1
# Generation: 192	String: Aakarshit SrivastUva	Fitness: 1
# Generation: 193	String: Aakarshit SrivastUva	Fitness: 1
# Generation: 194	String: Aakarshit SrivastUva	Fitness: 1
# Generation: 195	String: Aakarshit SrivastUva	Fitness: 1
# Generation: 196	String: Aakarshit SrivastUva	Fitness: 1
# Generation: 197	String: Aakarshit SrivastUva	Fitness: 1
# Generation: 198	String: Aakarshit SrivastUva	Fitness: 1
# Generation: 199	String: Aakarshit SrivastUva	Fitness: 1
# Generation: 200	String: Aakarshit SrivastUva	Fitness: 1
# Generation: 201	String: Aakarshit SrivastUva	Fitness: 1
# Generation: 202	String: Aakarshit SrivastUva	Fitness: 1
# Generation: 203	String: Aakarshit SrivastUva	Fitness: 1
# Generation: 204	String: Aakarshit SrivastUva	Fitness: 1
# Generation: 205	String: Aakarshit SrivastUva	Fitness: 1
# Generation: 206	String: Aakarshit SrivastUva	Fitness: 1
# Generation: 207	String: Aakarshit SrivastUva	Fitness: 1
# Generation: 208	String: Aakarshit SrivastUva	Fitness: 1
# Generation: 209	String: Aakarshit SrivastUva	Fitness: 1
# Generation: 210	String: Aakarshit SrivastUva	Fitness: 1
# Generation: 211	String: Aakarshit SrivastUva	Fitness: 1
# Generation: 212	String: Aakarshit SrivastUva	Fitness: 1
# Generation: 213	String: Aakarshit SrivastUva	Fitness: 1
# Generation: 214	String: Aakarshit SrivastUva	Fitness: 1
# Generation: 215	String: Aakarshit SrivastUva	Fitness: 1
# Generation: 216	String: Aakarshit SrivastUva	Fitness: 1
# Generation: 217	String: Aakarshit SrivastUva	Fitness: 1
# Generation: 218	String: Aakarshit SrivastUva	Fitness: 1
# Generation: 219	String: Aakarshit SrivastUva	Fitness: 1
# Generation: 220	String: Aakarshit SrivastUva	Fitness: 1
# Generation: 221	String: Aakarshit SrivastUva	Fitness: 1
# Generation: 222	String: Aakarshit SrivastUva	Fitness: 1
# Generation: 223	String: Aakarshit SrivastUva	Fitness: 1
# Generation: 224	String: Aakarshit SrivastUva	Fitness: 1
# Generation: 225	String: Aakarshit Srivastava	Fitness: 0

# %%
from math import inf
import random
import string

def generate_random_string(length):
    return ''.join(random.choice(string.ascii_letters + ' ') for _ in range(length))

def fitness(target, test_str):
    score = 0
    for i in range(len(target)):
        if target[i] == test_str[i]:
            score += 1
    return score

def crossover(parent1, parent2):
    crossover_point = random.randint(0, len(parent1) - 1)
    child1 = parent1[:crossover_point] + parent2[crossover_point:]
    child2 = parent2[:crossover_point] + parent1[crossover_point:]
    return child1, child2

def mutate(child, mutation_rate):
    mutated_child = ''
    for char in child:
        if random.random() < mutation_rate:
            mutated_child += random.choice(string.ascii_letters + ' ')
        else:
            mutated_child += char
    return mutated_child

def genetic_algorithm(target, population_size, mutation_rate, max_generations):
    population = [generate_random_string(len(target)) for _ in range(population_size)]
    generation = 0
    while generation < max_generations:
        population = sorted(population, key=lambda x: fitness(target, x), reverse=True)
        if fitness(target, population[0]) == len(target):
            return population[0], generation
        next_generation = [population[0]]  # Elitism: Keep the best solution
        while len(next_generation) < population_size:
            parent1, parent2 = random.choices(population[:int(population_size/2)], k=2)
            child1, child2 = crossover(parent1, parent2)
            child1 = mutate(child1, mutation_rate)
            child2 = mutate(child2, mutation_rate)
            next_generation.extend([child1, child2])
        population = next_generation
        generation += 1
    return None, generation

if __name__ == "__main__":
    target_string = "Aakarshit Srivastava"
    population_size = 100
    mutation_rate = 0.01
    max_generations = 100
    
    solution, generations = genetic_algorithm(target_string, population_size, mutation_rate, max_generations)
    if solution:
        print(f"Solution found in {generations} generations: {solution}")
    else:
        print("No solution found within the maximum number of generations.")
# Out:
# No solution found within the maximum number of generations.
